# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datos_perfumes_douglas.csv")

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.insert(0, 'tienda', "douglas")

# %%
def convertir_a_minusculas(valor):
    if isinstance(valor, str):
        return valor.lower()
    return valor

df = df.map(convertir_a_minusculas)

# %%
df['categoria'] = df['categoria'].str.replace('fragancias de hombre', 'hombre')
df['categoria'] = df['categoria'].str.replace('fragancias de mujer', 'mujer')

# %%
def mapear_tipos_y_limpiar(df):    

    mapping = {
        'perfume'                : 'parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau de  parfum'         : 'eau de parfum',
        'eau parfumee'           : 'eau de parfum',
        'eau parfumeé'           : 'eau de parfum',
        'extrait de parfum'      : 'parfum',
        'essence de parfum'      : 'parfum',
        'eau detoilette'         : 'eau de toilette',
        'eau fraîche'            : 'eau de cologne',
        'para hombre'            : '',
        'para mujer'             : '',
        'para  mujer'            : '',
        'unisex'                 : '',
        'intense'                : '',
        'extreme'                : '',
        'légère'                 : '',
        'cologne spray'          : '',
        'el ritual perfumado -'  : '',
        'y vaporizador de viaje' : ''
    }

    for name, replacement in mapping.items():
        df['tipo'] = df['tipo'].str.replace(name, replacement, regex=False)

    df['tipo'] = df['tipo'].str.strip()
    
    return df

mapear_tipos_y_limpiar(df)
# Out:
#        tienda categoria               marca              nombre  \
# 0     douglas    hombre              chanel      bleu de chanel
# 1     douglas    hombre              chanel        allure homme
# 2     douglas    hombre  yves saint laurent  la nuit de l’homme
# 3     douglas    hombre              armani        acqua di giò
# 4     douglas    hombre           hugo boss        boss bottled
# ...       ...       ...                 ...                 ...
# 3695  douglas     mujer          jil sander                 sun
# 3696  douglas     mujer  van cleef & arpels               first
# 3697  douglas     mujer                dior         joy by dior
# 3698  douglas     mujer              chanel                coco
# 3699  douglas     mujer              chanel  chance eau fraîche
#
#                  tipo precio_sin_desc   descuento precio_con_desc  valoracion  \
# 0       eau de parfum        127,99 €  no aparece   sin descuento         5.0
# 1     eau de toilette        115,99 €  no aparece   sin descuento         NaN
# 2     eau de toilette         54,95 €  no aparece         38,99 €         5.0
# 3     eau de toilette         70,99 €  no aparece         40,99 €         5.0
# 4     eau de toilette         71,99 €  no aparece         29,99 €         5.0
# ...               ...             ...         ...             ...         ...
# 3695     gel de ducha          9,99 €  no aparece   sin descuento         NaN
# 3696    eau de parfum        124,99 €  no aparece   sin descuento         NaN
# 3697      desodorante         49,99 €  no aparece   sin descuento         NaN
# 3698    eau de parfum        123,99 €  no aparece   sin descuento         NaN
# 3699    eau de parfum        157,00 €  no aparece   sin descuento         NaN
#
#       num_valoraciones
# 0                  1.0
# 1                  NaN
# 2                  2.0
# 3               2290.0
# 4                  3.0
# ...                ...
# 3695               NaN
# 3696               NaN
# 3697               NaN
# 3698               NaN
# 3699               NaN
#
# [3700 rows x 10 columns]

# %%
df.loc[df['tipo'] == 'cologne', 'tipo'] = 'eau de cologne'

# %%
def clean_prices(df, columns):
    
    for col in columns:
        
        df[col] = df[col].str.replace('[^0-9,]', '', regex=True) 
        df[col] = df[col].str.replace(',', '.', regex=True)
        df[col] = df[col].replace('', '0', regex=True)
        df[col] = df[col].astype(float)  

columns = ['descuento', 'precio_con_desc','precio_sin_desc']

clean_prices(df, columns)

# %%
columns = ['valoracion', 'num_valoraciones']

for col in columns:
    df[col] = df[col].replace(['sin valoracion', 'sin valoraciones'], np.nan)

# %%
df.to_csv('datos_perfumes_douglas_filtrados.csv', index=False)

# %%
df['tipo'].value_counts()
# Out:
# tipo
# eau de parfum                     1671
# eau de toilette                   1167
# set de fragancia                   219
# parfum                             187
# eau de cologne                     145
# aftershave                          78
# loción corporal                     51
# spray corporal                      46
# desodorante                         32
# gel de ducha                        21
# parfum para cabello                 16
# gel de ducha perfumado              14
# cuidado anticelulítico               9
# calendario de adviento               5
# crema para el cuerpo                 4
# vaporizador                          4
# eau fraiche                          3
# cofre higiene personal               3
# champú capilar                       2
# tratamiento corporal perfumado       2
# jabón                                2
# crema facial                         2
# cofre                                1
# fluido corporal                      1
# maquinilla de afeitar                1
# toalla                               1
# desodorante perfumado                1
# set de tratamiento facial            1
# crema de afeitado                    1
# iluminador                           1
# acondicionador capilar               1
# bálsamo facial                       1
# espuma de ducha                      1
# Name: count, dtype: int64

# %%
# Función para actualizar Con Descuento
def actualizar_valor(row):
    if row['precio_con_desc'] == 0.00:
        return row['precio_sin_desc']
    else:
        return row['precio_con_desc']

# Aplicar la función a cada fila del DataFrame
df['precio_con_desc'] = df.apply(actualizar_valor, axis=1)

# %%
df['descuento'] = ((df['precio_sin_desc'] - df['precio_con_desc']) / df['precio_sin_desc']) * 100
df['descuento'] = df['descuento'].round(2)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2904 entries, 0 to 3697
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tienda            2904 non-null   object
#  1   categoria         2904 non-null   object
#  2   marca             2769 non-null   object
#  3   nombre            2904 non-null   object
#  4   tipo              2898 non-null   object
#  5   precio_sin_desc   2904 non-null   float64
#  6   descuento         2904 non-null   float64
#  7   precio_con_desc   2904 non-null   float64
#  8   valoracion        421 non-null    float64
#  9   num_valoraciones  421 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 249.6+ KB

# %%
lista_tipos = ['eau de parfum', 'eau de toilette', 'parfum', 'eau de cologne']
df = df[df["tipo"].isin(lista_tipos)].reset_index(drop=True)

# %%
df
# Out:
#        tienda categoria               marca              nombre  \
# 0     douglas    hombre              chanel      bleu de chanel
# 1     douglas    hombre              chanel        allure homme
# 2     douglas    hombre  yves saint laurent  la nuit de l’homme
# 3     douglas    hombre              armani        acqua di giò
# 4     douglas    hombre           hugo boss        boss bottled
# ...       ...       ...                 ...                 ...
# 2417  douglas     mujer  yves saint laurent       ysl klassiker
# 2418  douglas     mujer  yves saint laurent       ysl klassiker
# 2419  douglas     mujer  van cleef & arpels               first
# 2420  douglas     mujer                dior             j’adore
# 2421  douglas     mujer  van cleef & arpels               first
#
#                  tipo  precio_sin_desc  descuento  precio_con_desc  \
# 0       eau de parfum           127.99       0.00           127.99
# 1     eau de toilette           115.99       0.00           115.99
# 2     eau de toilette            54.95      29.04            38.99
# 3     eau de toilette            70.99      42.26            40.99
# 4     eau de toilette            71.99      58.34            29.99
# ...               ...              ...        ...              ...
# 2417    eau de parfum           160.00      61.25            62.00
# 2418    eau de parfum            53.00       0.00            53.00
# 2419  eau de toilette           116.99       0.00           116.99
# 2420    eau de parfum            59.99       0.00            59.99
# 2421    eau de parfum           124.99       0.00           124.99
#
#       valoracion  num_valoraciones
# 0            5.0               1.0
# 1            NaN               NaN
# 2            5.0               2.0
# 3            5.0            2290.0
# 4            5.0               3.0
# ...          ...               ...
# 2417         NaN               NaN
# 2418         NaN               NaN
# 2419         NaN               NaN
# 2420         5.0               1.0
# 2421         NaN               NaN
#
# [2422 rows x 10 columns]

# %%
df.to_csv('datos_perfumes_douglas_filtrados.csv', index=False)
